# %% [markdown]
# <a href="https://colab.research.google.com/github/suhaschowdary/bert_humor/blob/bert_humor/bert_humor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/suhaschowdary/bert_humor.git
# Out:
# Cloning into 'bert_humor'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 56 (delta 1), reused 48 (delta 0), pack-reused 0
# Unpacking objects: 100% (56/56), done.

# %%
#install dependencies

# !pip3 install https://download.pytorch.org/whl/cu90/torch-1.0.0-cp36-cp36m-linux_x86_64.whl

# !pip3 install torch torchvision

# !pip install pytorch-pretrained-bert
# Out:
# ...
#      |████████████████████████████████| 591.8MB 30kB/s
# ...
#   Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# ...
#      |████████████████████████████████| 133kB 3.4MB/s
# ...

# %%
import os
os.chdir('bert_humor')

# %%
# !python convert_tf_checkpoint_to_pytorch.py
# Out:
# Building PyTorch model from configuration: {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# Converting TensorFlow checkpoint from /content/bert_humor/pybert/model/pretrain/uncased_L-12_H-768_A-12/bert_model.ckpt
# Loading TF weight bert/embeddings/LayerNorm/beta with shape [768]
# Loading TF weight bert/embeddings/LayerNorm/gamma with shape [768]
# Loading TF weight bert/embeddings/position_embeddings with shape [512, 768]
# Loading TF weight bert/embeddings/token_type_embeddings with shape [2, 768]
# Loading TF weight bert/embeddings/word_embeddings with shape [30522, 768]
# Loading TF weight bert/encoder/layer_0/attention/output/LayerNorm/beta with shape [768]
# ...

# %%
# !python train_bert_humor.py
# Out:
# [2019-05-18 22:51:33]: bert train_bert_humor.py[line:27] INFO  seed is 2018
# [2019-05-18 22:51:33]: bert train_bert_humor.py[line:30] INFO  starting load data from disk
# 100% 299382/299382 [00:07<00:00, 39964.11it/s]
# [2019-05-18 22:51:41]: bert data_transformer.py[line:75] INFO  train val split
# Merge: 299379it [00:00, 1107415.75it/s]
# write data to disk: 100% 239504/239504 [00:00<00:00, 649856.41it/s]
# write data to disk: 100% 59875/59875 [00:00<00:00, 635309.29it/s]
# [2019-05-18 22:51:43]: bert train_bert_humor.py[line:78] INFO  initializing model
# [2019-05-18 22:51:46]: bert train_bert_humor.py[line:102] INFO  initializing callbacks
# [2019-05-18 22:51:46]: bert train_bert_humor.py[line:120] INFO  training model....
# model summary info:
# -----------------------------------------------------------------------
#              Layer (type)                Input Shape         Param #
# ...
#               BertModel-1                  [-1, 256]               0
# ...

# %%
# !python inference.py
# Out:
# [2019-05-18 20:17:29]: bert inference.py[line:23] INFO  seed is 2018
# [2019-05-18 20:17:29]: bert inference.py[line:26] INFO  starting load data from disk
# 100% 74845/74845 [00:02<00:00, 34491.81it/s]
# [2019-05-18 20:17:31]: bert inference.py[line:52] INFO  initializing model
# [2019-05-18 20:17:35]: bert inference.py[line:57] INFO  model predicting....
# [predict]3743/3743[>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100%74845 74845
# <class 'numpy.ndarray'>
# [[1]
#  [1]
#  [1]
#  ...
#  [0]
#  [0]
# ...
